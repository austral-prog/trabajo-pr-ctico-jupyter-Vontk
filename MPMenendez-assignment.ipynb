# %% [markdown]
# # Assignment
#
# The assignment will require you to complete cells, create new ones, and move around some cells. You need to familiarize yourself with the Jupyter notebook interface. You can find a tutorial [here](https://www.dataquest.io/blog/jupyter-notebook-tutorial/).

# %% [markdown]
# ---

# %% [markdown]
# # Ejercicio nro 1
# ## Matias Perez Menendez
# ### Universidad Austral
# #### mperezmenendez@mail.austral.edu.ar
# ![WIN_20240322_11_55_53_Pro.jpg](attachment:8c64b3f7-f95c-41b1-9a9a-3f2d6f0fd77f.jpg)
#
# una imagen de matias, bautista y juanito en clase de programacion.

# %% [raw]
# ---

# %% [markdown]
# # Ejercicio nro 5

# %% [markdown]
# ### suma

# %%
ariel=3
benicio=7
print(benicio + ariel)
# Out:
# 10

# %% [markdown]
# ### resta

# %%
print(benicio - ariel)
# Out:
# 4

# %% [markdown]
# ### multiplicacion

# %%
print(benicio * ariel)
# Out:
# 21

# %% [markdown]
# ### division

# %%
print(benicio / ariel)
# Out:
# 2.3333333333333335
